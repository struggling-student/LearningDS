# %%
import pandas as pd

# %%
paziente1 = pd.read_csv('./paziente1.csv', sep=';')
paziente2 = pd.read_csv('./paziente2.csv', sep=';')

paziente1.head()
paziente2.head()
# Out:
#       timestamp                    datetime  Head.state   Head.px   Head.py  \
# 0  1.665675e+09  2022-10-13_16:30:47.568163         2.0  1.867225  0.924170
# 1  1.665675e+09  2022-10-13_16:30:48.032363         2.0  1.764842  0.888837
# 2  1.665675e+09  2022-10-13_16:30:48.161535         2.0  1.727034  0.901317
# 3  1.665675e+09  2022-10-13_16:30:48.228919         2.0  1.718505  0.892424
# 4  1.665675e+09  2022-10-13_16:30:48.294931         2.0  1.690501  0.906538
#
#     Head.pz  Head.rx  Head.ry  Head.rz  Neck.state  ...  AnkleLeft.rx  \
# 0  4.232417      0.0      0.0      0.0         2.0  ...     -0.363849
# 1  4.137678      0.0      0.0      0.0         2.0  ...     -0.408662
# 2  4.051424      0.0      0.0      0.0         2.0  ...     -0.395152
# 3  4.017233      0.0      0.0      0.0         2.0  ...     -0.376633
# 4  3.972101      0.0      0.0      0.0         2.0  ...     -0.354833
#
#    AnkleLeft.ry  AnkleLeft.rz  FootLeft.state  FootLeft.px  FootLeft.py  \
# ...
